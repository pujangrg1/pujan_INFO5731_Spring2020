# %%
#define variables
status = []
name = []
summary = []
jurisdiction = []
api = "https://api.case.law/v1/cases/"

# %%
# collect data from 1000 cases
import requests
for caseID in range(1,1001):
    url = api + str(caseID) + "/?full_case=true"
    response = requests.get(url, headers={'Authorization': 'Token 64467cd6c2207b431cca220c9ff9c84c39d1ef91'})
    case = response.json()
    status.append(case['casebody']['status'])
    name.append(case['name'])
    jurisdiction.append(case['jurisdiction']['name_long'])
    if(case['casebody']['data']['opinions'] == []):
        case_body = case['casebody']['data']['head_matter']
        summary.append(case_body[0])
    else:
        case_body = case['casebody']['data']['opinions']
        summary.append(case_body[0]['text'])

# %%
import pandas as pd
df = pd.DataFrame({'Case Name': name,'Status': status,'Jurisdiction': jurisdiction, 'Summary': summary})
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Lowercase

# %%
df['LowerCase'] = df['Summary'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# #### Removed Punctuation

# %%
import string
df['Removed Punctuation'] = df['LowerCase'].apply(lambda x: "".join(x.lower() for x in x if x not in string.punctuation))
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# #### Removed Noise

# %%
df['Removed Noise'] = df['Removed Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x.isalnum()))
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# #### Removed Stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Removed StopWords'] = df['Removed Noise'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# #### Removing Frequent Words

# %%
frequent_words = list(pd.Series(' '.join(df['Summary']).split()).value_counts()[:15].index)
df["Frequent Words"] = df['Removed StopWords'].apply(lambda x: ' '.join([i for i in x.split() if i not in frequent_words]))
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# #### Stemming

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['Stemming'] = df['Frequent Words'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# #### Word Tokenize

# %%
from textblob import TextBlob
df['Word Tokenize'] = df['Frequent Words'].apply(lambda x: TextBlob(x).words)
df
# Out:
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# 998  Joe David CHILDRESS, Petitioner-Appellant, v. ...     ok  United States
# 999  Phyllis MERRIWEATHER, Plaintiff-Appellee, v. F...     ok  United States
#
# ...

# %% [markdown]
# #### Lemmatization

# %%
from textblob import Word
import nltk
nltk.download('wordnet')
df['Lemmatization'] = df['Word Tokenize'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x]))
df
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pujangurung/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                              Case Name Status   Jurisdiction  \
# 0                   CHARLES BURDETTE v. CITY OF BOSTON     ok  Massachusetts
# 1    MERRIMACK VALLEY NATIONAL BANK v. G. STEWART B...     ok  Massachusetts
# 2    DAVID M. SCHNEIDERMAN v. COMMONWEALTH OF MASSA...     ok  Massachusetts
# 3       ALVAN E. LEVENSON, TRUSTEE v. JOHN C. BERTOLET     ok  Massachusetts
# 4    COMMERCIAL PLASTICS AND SUPPLY CORP. v. ACE DA...     ok  Massachusetts
# ..                                                 ...    ...            ...
# 995  PUEBLO OF SAN ILDEFONSO, Plaintiff-Appellant, ...     ok  United States
# 996  Henry L. CROFT, Jr.; Carol Croft, Individually...     ok  United States
# 997  Irma COLLINS, Plaintiff-Appellee, v. BLUE CROS...     ok  United States
# ...

# %%
test_data = df[['Case Name','Lemmatization']]

# %%
test_data.to_csv('test_data.csv', index = False)
